# %%
import numpy as np
import pandas as pd
import os
import gc
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# === Label mapping ===
id_to_emotion_mapper = {0:'Angry',1:'Contempt',2:'Disgust',3:'Fear',4:'Happy',5:'Natural',6:'Sad',7:'Sleepy',8:'Surprised'}
mapping_to_new = {0:0,1:-1,2:-1,3:4,4:1,5:2,6:3,7:2,8:4}
new_emotion_mapper = {0:'Angry',1:'Happy',2:'Neutral',3:'Sad',4:'Surprised'}

# === Root folder ===
root = '/kaggle/input/8-facial-expressions-for-yolo/9 Facial Expressions you need'

# === Dataset generator ===
def dataset_generator(dataset='training', aug=True):
    dataset = dataset.lower()
    if dataset == 'training':
        folder = 'train'
    elif dataset == 'validation':
        folder = 'valid'
    elif dataset == 'testing':
        folder = 'test'
    else:
        print('\nError: wrong dataset/folder name provided\n')
        return -1
    
    images, labels = [], []
    available = [6000, 6000, 6000, 6000, 6000]
    
    dir_folder = os.path.join(root, folder)
    dir_folder_images = os.path.join(dir_folder, 'images')
    dir_folder_labels = os.path.join(dir_folder, 'labels')
    
    label_list = os.listdir(dir_folder_labels)
    for label_filename in label_list:
        label_path = os.path.join(dir_folder_labels, label_filename)
        with open(label_path) as f:
            line = f.readline().strip().split()
            if not line: 
                continue
            label_idx = int(line[0])
            new_idx = mapping_to_new[label_idx]
            if new_idx >= 0 and available[new_idx] >= 0:
                oneHot_label = [0, 0, 0, 0, 0]
                oneHot_label[new_idx] = 1
                img_path_jpg = os.path.join(dir_folder_images, label_filename.replace('.txt', '.jpg'))
                img_path_png = os.path.join(dir_folder_images, label_filename.replace('.txt', '.png'))
                img_path = img_path_jpg if os.path.exists(img_path_jpg) else (img_path_png if os.path.exists(img_path_png) else None)
                if img_path:
                    available[new_idx] -= 1
                    img = cv2.imread(img_path)
                    if img is None:
                        continue
                    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                    img = cv2.resize(img, (224, 224))
                    images.append(img)
                    labels.append(oneHot_label)
    
    images = np.array(images)
    labels = np.array(labels)
    print(f'Shape of images: {images.shape}, labels: {labels.shape}')
    
    temp_map = {0:0, 1:0, 2:0, 3:0, 4:0}
    for i in labels:
        temp_map[np.argmax(i)] += 1
    print("\nLabel distribution:\n", temp_map)
    
    if aug and len(images) > 0:
        generator = ImageDataGenerator(
            width_shift_range=0.2,
            height_shift_range=0.2,
            rotation_range=10,
            horizontal_flip=True,
            zoom_range=0.1,
            preprocessing_function=preprocess_input
        )
        dataset = generator.flow(images, labels)
        del images, labels
        gc.collect()
        return dataset
    else:
        return images, labels


# === Data Preparation ===
train_dataset = dataset_generator('training')
val_dataset = dataset_generator('validation')
test_images, test_labels = dataset_generator('testing', aug=False)


# === Model ===
base_model = MobileNetV2(input_shape=(224,224,3), weights='imagenet', include_top=False)
for layer in base_model.layers:
    layer.trainable = True

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.4)(x)
preds = Dense(5, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=preds)

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy', tf.keras.metrics.AUC(name='AUC')]
)

# === Callbacks ===
callbacks = [
    ReduceLROnPlateau(monitor='val_accuracy', patience=3, factor=0.5, verbose=1)
]

# === Training ===
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=40,  # no early stopping, run all epochs
    callbacks=callbacks
)

# === Accuracy Graph ===
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1, len(train_acc) + 1)

plt.figure(figsize=(10,6))
plt.plot(epochs, train_acc, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()


# === Evaluate on Test Data ===
predictions = model.predict(preprocess_input(test_images))
y_pred = np.argmax(predictions, axis=1)
y_true = np.argmax(test_labels, axis=1)

loss, accuracy, auc = model.evaluate(preprocess_input(test_images), test_labels)
print(f"\nTest Accuracy: {accuracy:.4f}")
print(f"Test AUC: {auc:.4f}")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=list(new_emotion_mapper.values()))
disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()

# === Detailed Metrics ===
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=list(new_emotion_mapper.values())))

# === Save model ===
model.save('unnorm_224dim_image85perplus_full40epochs.h5')
# Out:
# 2025-11-04 14:12:31.558061: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762265551.759757      37 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762265551.814051      37 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape of images: (30005, 224, 224, 3), labels: (30005, 5)
#
# Label distribution:
#  {0: 6001, 1: 6001, 2: 6001, 3: 6001, 4: 6001}
# Shape of images: (1530, 224, 224, 3), labels: (1530, 5)
#
# Label distribution:
#  {0: 258, 1: 387, 2: 210, 3: 312, 4: 363}
# Shape of images: (1534, 224, 224, 3), labels: (1534, 5)
#
# Label distribution:
#  {0: 297, 1: 407, 2: 169, 3: 298, 4: 363}
# I0000 00:00:1762266399.609239      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762266439.776433      96 service.cc:148] XLA service 0x7bdb50004bc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1762266439.777203      96 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1762266443.047561      96 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1762266449.350021      96 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1762266449.546508      96 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   1/938 ━━━━━━━━━━━━━━━━━━━━ 14:37:12 56s/step - AUC: 0.4347 - accuracy: 0.1250 - loss: 2.1406
# I0000 00:00:1762266460.681225      96 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 596/938 ━━━━━━━━━━━━━━━━━━━━ 1:44 306ms/step - AUC: 0.7835 - accuracy: 0.4899 - loss: 1.2947
# E0000 00:00:1762266650.345061      96 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1762266650.543727      96 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 382s 348ms/step - AUC: 0.8082 - accuracy: 0.5220 - loss: 1.2174 - val_AUC: 0.6039 - val_accuracy: 0.2882 - val_loss: 6.5959 - learning_rate: 0.0010
# Epoch 2/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 310s 330ms/step - AUC: 0.9123 - accuracy: 0.6827 - loss: 0.8359 - val_AUC: 0.8029 - val_accuracy: 0.5784 - val_loss: 2.3295 - learning_rate: 0.0010
# Epoch 3/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 301s 321ms/step - AUC: 0.9347 - accuracy: 0.7268 - loss: 0.7197 - val_AUC: 0.7813 - val_accuracy: 0.5248 - val_loss: 2.9121 - learning_rate: 0.0010
# Epoch 4/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 300s 319ms/step - AUC: 0.9436 - accuracy: 0.7474 - loss: 0.6674 - val_AUC: 0.8625 - val_accuracy: 0.6183 - val_loss: 1.4471 - learning_rate: 0.0010
# Epoch 5/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 309s 330ms/step - AUC: 0.9482 - accuracy: 0.7658 - loss: 0.6387 - val_AUC: 0.8063 - val_accuracy: 0.5320 - val_loss: 2.0471 - learning_rate: 0.0010
# Epoch 6/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 305s 325ms/step - AUC: 0.9550 - accuracy: 0.7767 - loss: 0.5939 - val_AUC: 0.9063 - val_accuracy: 0.6935 - val_loss: 1.1412 - learning_rate: 0.0010
# Epoch 7/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 301s 321ms/step - AUC: 0.9582 - accuracy: 0.7871 - loss: 0.5716 - val_AUC: 0.8807 - val_accuracy: 0.6549 - val_loss: 1.3276 - learning_rate: 0.0010
# Epoch 8/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 303s 323ms/step - AUC: 0.9626 - accuracy: 0.7986 - loss: 0.5400 - val_AUC: 0.8740 - val_accuracy: 0.6333 - val_loss: 1.3419 - learning_rate: 0.0010
# Epoch 9/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - AUC: 0.9650 - accuracy: 0.8054 - loss: 0.5212
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 304s 324ms/step - AUC: 0.9650 - accuracy: 0.8054 - loss: 0.5212 - val_AUC: 0.9019 - val_accuracy: 0.6778 - val_loss: 1.0216 - learning_rate: 0.0010
# Epoch 10/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 304s 324ms/step - AUC: 0.9752 - accuracy: 0.8370 - loss: 0.4335 - val_AUC: 0.9506 - val_accuracy: 0.7693 - val_loss: 0.6665 - learning_rate: 5.0000e-04
# Epoch 11/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 302s 322ms/step - AUC: 0.9785 - accuracy: 0.8498 - loss: 0.4025 - val_AUC: 0.9610 - val_accuracy: 0.8078 - val_loss: 0.5865 - learning_rate: 5.0000e-04
# Epoch 12/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 302s 321ms/step - AUC: 0.9827 - accuracy: 0.8626 - loss: 0.3617 - val_AUC: 0.9633 - val_accuracy: 0.8033 - val_loss: 0.5643 - learning_rate: 5.0000e-04
# Epoch 13/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 307s 327ms/step - AUC: 0.9832 - accuracy: 0.8698 - loss: 0.3524 - val_AUC: 0.9599 - val_accuracy: 0.7935 - val_loss: 0.6042 - learning_rate: 5.0000e-04
# Epoch 14/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 310s 331ms/step - AUC: 0.9841 - accuracy: 0.8673 - loss: 0.3433 - val_AUC: 0.9629 - val_accuracy: 0.8190 - val_loss: 0.5589 - learning_rate: 5.0000e-04
# Epoch 15/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 303s 323ms/step - AUC: 0.9858 - accuracy: 0.8769 - loss: 0.3243 - val_AUC: 0.9543 - val_accuracy: 0.7908 - val_loss: 0.6774 - learning_rate: 5.0000e-04
# Epoch 16/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 302s 322ms/step - AUC: 0.9863 - accuracy: 0.8824 - loss: 0.3153 - val_AUC: 0.9612 - val_accuracy: 0.8118 - val_loss: 0.6085 - learning_rate: 5.0000e-04
# Epoch 17/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - AUC: 0.9875 - accuracy: 0.8869 - loss: 0.2996
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 301s 321ms/step - AUC: 0.9875 - accuracy: 0.8869 - loss: 0.2996 - val_AUC: 0.9576 - val_accuracy: 0.8000 - val_loss: 0.6307 - learning_rate: 5.0000e-04
# Epoch 18/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 306s 326ms/step - AUC: 0.9906 - accuracy: 0.9052 - loss: 0.2564 - val_AUC: 0.9708 - val_accuracy: 0.8418 - val_loss: 0.4940 - learning_rate: 2.5000e-04
# Epoch 19/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 303s 323ms/step - AUC: 0.9932 - accuracy: 0.9191 - loss: 0.2187 - val_AUC: 0.9679 - val_accuracy: 0.8373 - val_loss: 0.5220 - learning_rate: 2.5000e-04
# Epoch 20/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 303s 323ms/step - AUC: 0.9938 - accuracy: 0.9224 - loss: 0.2099 - val_AUC: 0.9614 - val_accuracy: 0.8268 - val_loss: 0.6337 - learning_rate: 2.5000e-04
# Epoch 21/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 304s 324ms/step - AUC: 0.9935 - accuracy: 0.9239 - loss: 0.2073 - val_AUC: 0.9715 - val_accuracy: 0.8490 - val_loss: 0.5109 - learning_rate: 2.5000e-04
# Epoch 22/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 302s 322ms/step - AUC: 0.9945 - accuracy: 0.9291 - loss: 0.1929 - val_AUC: 0.9671 - val_accuracy: 0.8405 - val_loss: 0.5658 - learning_rate: 2.5000e-04
# Epoch 23/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 300s 320ms/step - AUC: 0.9949 - accuracy: 0.9291 - loss: 0.1857 - val_AUC: 0.9696 - val_accuracy: 0.8510 - val_loss: 0.5376 - learning_rate: 2.5000e-04
# Epoch 24/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 300s 320ms/step - AUC: 0.9950 - accuracy: 0.9357 - loss: 0.1794 - val_AUC: 0.9579 - val_accuracy: 0.8288 - val_loss: 0.6743 - learning_rate: 2.5000e-04
# Epoch 25/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 299s 319ms/step - AUC: 0.9952 - accuracy: 0.9342 - loss: 0.1740 - val_AUC: 0.9663 - val_accuracy: 0.8425 - val_loss: 0.5578 - learning_rate: 2.5000e-04
# Epoch 26/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - AUC: 0.9960 - accuracy: 0.9381 - loss: 0.1652
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 299s 319ms/step - AUC: 0.9960 - accuracy: 0.9381 - loss: 0.1652 - val_AUC: 0.9692 - val_accuracy: 0.8471 - val_loss: 0.5353 - learning_rate: 2.5000e-04
# Epoch 27/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 299s 318ms/step - AUC: 0.9968 - accuracy: 0.9473 - loss: 0.1421 - val_AUC: 0.9653 - val_accuracy: 0.8497 - val_loss: 0.5905 - learning_rate: 1.2500e-04
# Epoch 28/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 302s 321ms/step - AUC: 0.9975 - accuracy: 0.9517 - loss: 0.1276 - val_AUC: 0.9660 - val_accuracy: 0.8477 - val_loss: 0.5717 - learning_rate: 1.2500e-04
# Epoch 29/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 303s 323ms/step - AUC: 0.9977 - accuracy: 0.9559 - loss: 0.1192 - val_AUC: 0.9674 - val_accuracy: 0.8523 - val_loss: 0.5711 - learning_rate: 1.2500e-04
# Epoch 30/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 299s 319ms/step - AUC: 0.9977 - accuracy: 0.9560 - loss: 0.1181 - val_AUC: 0.9659 - val_accuracy: 0.8588 - val_loss: 0.6055 - learning_rate: 1.2500e-04
# Epoch 31/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 300s 319ms/step - AUC: 0.9975 - accuracy: 0.9580 - loss: 0.1162 - val_AUC: 0.9627 - val_accuracy: 0.8556 - val_loss: 0.6257 - learning_rate: 1.2500e-04
# Epoch 32/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 299s 319ms/step - AUC: 0.9978 - accuracy: 0.9595 - loss: 0.1102 - val_AUC: 0.9620 - val_accuracy: 0.8431 - val_loss: 0.6740 - learning_rate: 1.2500e-04
# Epoch 33/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - AUC: 0.9982 - accuracy: 0.9599 - loss: 0.1042
# Epoch 33: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 302s 322ms/step - AUC: 0.9982 - accuracy: 0.9599 - loss: 0.1042 - val_AUC: 0.9577 - val_accuracy: 0.8542 - val_loss: 0.7011 - learning_rate: 1.2500e-04
# Epoch 34/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 302s 321ms/step - AUC: 0.9985 - accuracy: 0.9631 - loss: 0.0951 - val_AUC: 0.9604 - val_accuracy: 0.8523 - val_loss: 0.6688 - learning_rate: 6.2500e-05
# Epoch 35/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 300s 319ms/step - AUC: 0.9986 - accuracy: 0.9675 - loss: 0.0882 - val_AUC: 0.9608 - val_accuracy: 0.8549 - val_loss: 0.6708 - learning_rate: 6.2500e-05
# Epoch 36/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - AUC: 0.9986 - accuracy: 0.9666 - loss: 0.0893
# Epoch 36: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 305s 325ms/step - AUC: 0.9986 - accuracy: 0.9666 - loss: 0.0893 - val_AUC: 0.9622 - val_accuracy: 0.8556 - val_loss: 0.6780 - learning_rate: 6.2500e-05
# Epoch 37/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 302s 322ms/step - AUC: 0.9988 - accuracy: 0.9712 - loss: 0.0799 - val_AUC: 0.9605 - val_accuracy: 0.8595 - val_loss: 0.6679 - learning_rate: 3.1250e-05
# Epoch 38/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 304s 324ms/step - AUC: 0.9988 - accuracy: 0.9688 - loss: 0.0797 - val_AUC: 0.9636 - val_accuracy: 0.8516 - val_loss: 0.6603 - learning_rate: 3.1250e-05
# Epoch 39/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 306s 326ms/step - AUC: 0.9989 - accuracy: 0.9714 - loss: 0.0759 - val_AUC: 0.9618 - val_accuracy: 0.8569 - val_loss: 0.6735 - learning_rate: 3.1250e-05
# Epoch 40/40
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - AUC: 0.9987 - accuracy: 0.9719 - loss: 0.0762
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 305s 325ms/step - AUC: 0.9987 - accuracy: 0.9719 - loss: 0.0762 - val_AUC: 0.9591 - val_accuracy: 0.8510 - val_loss: 0.7039 - learning_rate: 3.1250e-05
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - AUC: 0.9649 - accuracy: 0.8471 - loss: 0.6632
#
# Test Accuracy: 0.8462
# Test AUC: 0.9616
# Classification Report:
#               precision    recall  f1-score   support
#
#        Angry       0.84      0.77      0.81       297
#        Happy       0.95      0.93      0.94       407
#      Neutral       0.64      0.79      0.71       169
#          Sad       0.81      0.80      0.80       298
#    Surprised       0.88      0.87      0.88       363
#
#     accuracy                           0.85      1534
#    macro avg       0.83      0.83      0.83      1534
# weighted avg       0.85      0.85      0.85      1534
